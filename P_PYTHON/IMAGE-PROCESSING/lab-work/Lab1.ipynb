# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
img1=cv2.imread("../test-images/pa.jpg",cv2.IMREAD_GRAYSCALE)
img2=cv2.imread("../test-images/cake.jpg",cv2.IMREAD_GRAYSCALE)
cv2.imshow("img1",img1)
cv2.imshow("img2",img2)
cv2.waitKey()
# Out:
# -1

# %%
directory = r'D:/img_output/'
try:
    os.mkdir(directory)
except Exception as e:
    print(e)

image = cv2.imread('../test-images/pa.jpg')
cv2.imshow("Actual_Image",image)
intensity_matrix=np.ones(image.shape,dtype="uint8")*60
bi=cv2.add(image,intensity_matrix)
cv2.imshow("bright",bi)
di=cv2.subtract(image,intensity_matrix)
cv2.imshow("dark",di)
cv2.waitKey(0)

cv2.imwrite(directory+"bright.jpg",bi)
cv2.imwrite(directory+"dark.jpg",di)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'D:/img_output/'
# True

# %%
image = cv2.imread('../test-images/pa.jpg')
cv2.imshow('Original Image', image)
resized_down = cv2.resize(image, (500,500), interpolation= cv2.INTER_LINEAR)
resized_up = cv2.resize(image, (500,200), interpolation= cv2.INTER_LINEAR)
cv2.imshow('Resized Down by defining height and width', resized_down)
cv2.imshow('Resized Up image by defining height and width', resized_up)
cv2.waitKey()
# Out:
# -1

# %%
img1=cv2.imread("../test-images/pa.jpg")
height,width=img1.shape[:2]
mat=cv2.getRotationMatrix2D((width/2,height/2),60,1)
img=cv2.warpAffine(img1,mat,(width,height))
plt.imshow(img)

# %%
image = cv2.imread('../test-images/pa.jpg')
height, width = image.shape[:2]
quarter_height, quarter_width = height / 4, width / 4
T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])
img_translation = cv2.warpAffine(image, T, (width, height))
cv2.imshow("Originalimage", image)
cv2.imshow('Translation', img_translation)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.add(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.subtract(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.bitwise_and(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.bitwise_not(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.bitwise_or(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.bitwise_xor(cv2.resize(img1,(500,500)),cv2.resize(img2,(500,500)))
plt.imshow(img)

# %%
img1=cv2.imread("../test-images/pa.jpg")
img2=cv2.imread("../test-images/cake.jpg")
img=cv2.addWeighted(cv2.resize(img1,(500,500)),0.2,cv2.resize(img2,(500,500)),0.2,1)
plt.imshow(img)
